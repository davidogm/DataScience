# %% [markdown]
# <a href="https://colab.research.google.com/github/davidogm/DataScience/blob/main/ITBD/notebooks/05Pandas_Data_Science_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Loading data into Pandas

# %% [markdown]
# antes de cargarlo podemos abrirlo con un excel para ver el tipo de datos
#
# eso es lo que vamos a hacer cuando busquemos un tipo de datos para el trabajo

# %%
# !ls
# Out:
# sample_data

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f4ae5538-5517-4e24-8236-8f718508a227" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f4ae5538-5517-4e24-8236-8f718508a227">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pokemon.csv to pokemon.csv
# ...

# %%
# !ls
# Out:
# pokemon.csv  sample_data

# %%
import pandas as pd       ## Es la referencia más conocida

df = pd.read_csv('pokemon.csv')   # df es el dataframe


print(df.head(3))
#print(df.tail(4))

# otras formas de lectura, en caso de que los formatos de entrada sean diferentes
# df_xlsx = pd.read_excel('pokemon_data.xlsx')
# print(df_xlsx.head(3))

# df = pd.read_csv('pokemon_data.txt', delimiter='\t')
# en el caso del txt hay que especificar el delimitador, probar que pasa si no se hace
# print(df.head(5))

#df['HP']
# Out:
#    #       Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0  1  Bulbasaur  Grass  Poison  ...       65     45           1      False
# 1  2    Ivysaur  Grass  Poison  ...       80     60           1      False
# 2  3   Venusaur  Grass  Poison  ...      100     80           1      False
#
# [3 rows x 12 columns]

# %%
df.shape
# Out:
# (800, 12)

# %% [markdown]
# ## Reading Data in Pandas

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
## pongo las opciones entre comentarios para no tener que imprimir todo 

#### Read Headers
df.columns

## Read each Column
#print(df['Name'][0:5])
#print(df.Name [0:5])  # de la misma forma y sólo los 5 primeros, como head
#print(df[['Name', 'Type 1', 'HP']])
#print(df[['Name', 'Speed', 'Legendary']])


## Read Each Row, cogemos los índices de las filas que queramos
#print(df.iloc[0:4])  #index location
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# y esto es muy útil para coger elementos específicos
#for index, row in df.iterrows():
#     print(index, row['Name'])

# sólo muestra los elementos que cumplan los criterios del if
# operación muy potente, y crea un nuevo dataframe
df_if = df.loc[df['Type 1'] == "Grass"]
#print(df_if)
#df_if.shape



## Read a specific location (R,C) row, column
## aquí la búsqueda de las posiciones más específicas
## potencia de pandas, al poder seleccionar celdas de la matriz
#print(df.iloc[2,1])

# %%
df_if.shape
# Out:
# (70, 12)

# %%
df_if.head(3)
# Out:
#    #       Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0  1  Bulbasaur  Grass  Poison  ...       65     45           1      False
# 1  2    Ivysaur  Grass  Poison  ...       80     60           1      False
# 2  3   Venusaur  Grass  Poison  ...      100     80           1      False
#
# [3 rows x 12 columns]

# %%
df.shape
# Out:
# (800, 12)

# %% [markdown]
# esto es lo que me refiero, muchas opciones con el pandas, dataframe,
# df. para la ayuda

# %%
# muy útil para ver algunas medidas
df.describe()
# Out:
#               #          HP      Attack  ...     Sp. Def       Speed  Generation
# count  800.0000  800.000000  800.000000  ...  800.000000  800.000000   800.00000
# mean   400.5000   69.258750   79.001250  ...   71.902500   68.277500     3.32375
# std    231.0844   25.534669   32.457366  ...   27.828916   29.060474     1.66129
# min      1.0000    1.000000    5.000000  ...   20.000000    5.000000     1.00000
# 25%    200.7500   50.000000   55.000000  ...   50.000000   45.000000     2.00000
# 50%    400.5000   65.000000   75.000000  ...   70.000000   65.000000     3.00000
# 75%    600.2500   80.000000  100.000000  ...   90.000000   90.000000     5.00000
# max    800.0000  255.000000  190.000000  ...  230.000000  180.000000     6.00000
#
# [8 rows x 8 columns]

# %% [markdown]
# ## Sorting/Describing Data

# %% [markdown]
# muy útil porque nos permite ordenar por varios valores, type ascendente, HP descendente

# %%
df.sort_values(['Type 1', 'HP'], ascending=[1,0])
# Out:
#        #            Name Type 1  ... Speed  Generation  Legendary
# 520  521         Yanmega    Bug  ...    95           4      False
# 698  699       Volcarona    Bug  ...   100           5      False
# 231  232       Heracross    Bug  ...    85           2      False
# 232  233  Mega Heracross    Bug  ...    75           2      False
# 678  679        Accelgor    Bug  ...   145           5      False
# ..   ...             ...    ...  ...   ...         ...        ...
# 106  107          Krabby  Water  ...    50           1      False
# 125  126          Horsea  Water  ...    60           1      False
# 129  130          Staryu  Water  ...    85           1      False
# 139  140        Magikarp  Water  ...    80           1      False
# 381  382          Feebas  Water  ...    80           3      False
#
# [800 rows x 12 columns]

# %% [markdown]
# ## Making changes to the data
#
# podemos saltar un poco esto hacia los groupby

# %% [markdown]
# añadiendo nueva columna

# %%
df['Total2'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

df

# df = df.drop(columns=['Total'])

df['Total'] = df.iloc[:, 4:10].sum(axis=1)  # end parameter is exlusive

cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]]+cols[4:12]]

df.head(5)
# Out:
#    #           Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0  1      Bulbasaur  Grass  Poison  ...       65     45           1      False
# 1  2        Ivysaur  Grass  Poison  ...       80     60           1      False
# 2  3       Venusaur  Grass  Poison  ...      100     80           1      False
# 3  4  Mega Venusaur  Grass  Poison  ...      120     80           1      False
# 4  5     Charmander   Fire     NaN  ...       50     65           1      False
#
# [5 rows x 13 columns]

# %% [markdown]
# ## Saving our Data (Exporting into Desired Format)

# %%
 df.to_csv('modified.csv', index=False)

#df.to_excel('modified.xlsx', index=False)

df.to_csv('modified.txt', index=False, sep='\t')

# %%
# !ls
# Out:
# modified.csv  modified.txt  pokemon.csv  sample_data

# %% [markdown]
# ## Filtering Data

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

new_df.reset_index(drop=True, inplace=True)

new_df

new_df.to_csv('filtered.csv')

# %% [markdown]
# ## Conditional Changes

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.loc[df['Total'] > 500, ['Generation','Legendary']] = ['Test 1', 'Test 2']

df

#df = pd.read_csv('modified.csv')

#df
# Out:
#        #            Name   Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0      1       Bulbasaur    Grass  Poison  ...       65     45           1      False
# 1      2         Ivysaur    Grass  Poison  ...       80     60           1      False
# 2      3        Venusaur    Grass  Poison  ...      100     80      Test 1     Test 2
# 3      4   Mega Venusaur    Grass  Poison  ...      120     80      Test 1     Test 2
# 4      5      Charmander     Fire     NaN  ...       50     65           1      False
# ..   ...             ...      ...     ...  ...      ...    ...         ...        ...
# 795  796         Diancie     Rock   Fairy  ...      150     50      Test 1     Test 2
# 796  797    Mega Diancie     Rock   Fairy  ...      110    110      Test 1     Test 2
# 797  798  Hoopa Confined  Psychic   Ghost  ...      130     70      Test 1     Test 2
# 798  799   Hoopa Unbound  Psychic    Dark  ...      130     80      Test 1     Test 2
# ...

# %% [markdown]
# ## Aggregate Statistics (Groupby)

# %% [markdown]
# esto está muy chulo, agrupa por subgrupos, cuando son más de un elemento

# %%
dfM = pd.read_csv('modified.csv')
dfM.head
# Out:
# <bound method NDFrame.head of        #            Name   Type 1  ... Speed  Generation  Legendary
# 0      1       Bulbasaur    Grass  ...    45           1      False
# 1      2         Ivysaur    Grass  ...    60           1      False
# 2      3        Venusaur    Grass  ...    80           1      False
# 3      4   Mega Venusaur    Grass  ...    80           1      False
# 4      5      Charmander     Fire  ...    65           1      False
# ..   ...             ...      ...  ...   ...         ...        ...
# 795  796         Diancie     Rock  ...    50           6       True
# 796  797    Mega Diancie     Rock  ...   110           6       True
# 797  798  Hoopa Confined  Psychic  ...    70           6       True
# 798  799   Hoopa Unbound  Psychic  ...    80           6       True
# 799  800       Volcanion     Fire  ...    70           6       True
#
# [800 rows x 13 columns]>

# %%
dfM['count'] = 1

#print(dfM.groupby(['Type 2']).count()['count'])

dfM2 = dfM.groupby(['Type 1', 'Type 2']).count()['count']



# esto es algo súper útil para cuando se trabaja con muchos datos

# %%
dfM.head
# Out:
# <bound method NDFrame.head of        #            Name   Type 1  Type 2  ...  Speed  Generation  Legendary  count
# 0      1       Bulbasaur    Grass  Poison  ...     45           1      False      1
# 1      2         Ivysaur    Grass  Poison  ...     60           1      False      1
# 2      3        Venusaur    Grass  Poison  ...     80           1      False      1
# 3      4   Mega Venusaur    Grass  Poison  ...     80           1      False      1
# 4      5      Charmander     Fire     NaN  ...     65           1      False      1
# ..   ...             ...      ...     ...  ...    ...         ...        ...    ...
# 795  796         Diancie     Rock   Fairy  ...     50           6       True      1
# 796  797    Mega Diancie     Rock   Fairy  ...    110           6       True      1
# 797  798  Hoopa Confined  Psychic   Ghost  ...     70           6       True      1
# 798  799   Hoopa Unbound  Psychic    Dark  ...     80           6       True      1
# ...

# %%
dfM2.head(30)
# Out:
# Type 1    Type 2
# Bug       Electric     2
#           Fighting     2
#           Fire         2
#           Flying      14
#           Ghost        1
#           Grass        6
#           Ground       2
#           Poison      12
#           Rock         3
#           Steel        7
#           Water        1
# Dark      Dragon       3
#           Fighting     2
#           Fire         3
#           Flying       5
#           Ghost        2
#           Ice          2
#           Psychic      2
#           Steel        2
# Dragon    Electric     1
#           Fairy        1
#           Fire         1
#           Flying       6
#           Ground       5
#           Ice          3
#           Psychic      4
# Electric  Dragon       1
#           Fairy        1
#           Fire         1
#           Flying       5
# Name: count, dtype: int64

# %% [markdown]
# ## Working with large amounts of data

# %%
new_df = pd.DataFrame(columns=df.columns)

# divisiones para no cargar todo en memoria
# ejemplo, se corta en tamaños de 5 y vemos cómo queda
for df in pd.read_csv('modified.csv', chunksize=5):
  print ('chunk df')
  print (df)

#for df in pd.read_csv('modified.csv', chunksize=5):
#    results = df.groupby(['Type 1']).count()
    
#    new_df = pd.concat([new_df, results])
    
#print(new_df)

#print
# Out:
# chunk df
#    #           Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0  1      Bulbasaur  Grass  Poison  ...       65     45           1      False
# 1  2        Ivysaur  Grass  Poison  ...       80     60           1      False
# 2  3       Venusaur  Grass  Poison  ...      100     80           1      False
# 3  4  Mega Venusaur  Grass  Poison  ...      120     80           1      False
# 4  5     Charmander   Fire     NaN  ...       50     65           1      False
#
# [5 rows x 13 columns]
# chunk df
#     #              Name Type 1  Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 5   6        Charmeleon   Fire     NaN  ...       65     80           1      False
# 6   7         Charizard   Fire  Flying  ...       85    100           1      False
# 7   8  Mega Charizard X   Fire  Dragon  ...       85    100           1      False
# 8   9  Mega Charizard Y   Fire  Flying  ...      115    100           1      False
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(df)
# Out:
#        #            Name   Type 1 Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 795  796         Diancie     Rock  Fairy  ...      150     50           6       True
# 796  797    Mega Diancie     Rock  Fairy  ...      110    110           6       True
# 797  798  Hoopa Confined  Psychic  Ghost  ...      130     70           6       True
# 798  799   Hoopa Unbound  Psychic   Dark  ...      130     80           6       True
# 799  800       Volcanion     Fire  Water  ...       90     70           6       True
#
# [5 rows x 13 columns]

# %%
new_df.shape
# Out:
# (433, 13)

# %%
df.shape
# Out:
# (5, 13)
